# %%
# from pyecharts.globals import CurrentConfig, NotebookType
# CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker



c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.guangdong_city, Faker.values())], "广东")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts()
    )
    
)

# %%
c.load_javascript()

# %%
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', '广东':'https://assets.pyecharts.org/assets/v5/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="0eaf49a63b8448e5a59f0e3c8282c9de" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_0eaf49a63b8448e5a59f0e3c8282c9de = echarts.init(
#                     document.getElementById('0eaf49a63b8448e5a59f0e3c8282c9de'), 'white', {renderer: 'canvas'});
#                 var option_0eaf49a63b8448e5a59f0e3c8282c9de = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...

# %%
Faker.guangdong_city
# Out:
# ['汕头市', '汕尾市', '揭阳市', '阳江市', '肇庆市', '广州市', '惠州市']

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker



c = (
    Map()
    .add("商家A", [list(z) for z in zip(['北京市', '天津市', '河北省'], [34, 56, 98])], "广东")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts()
    )
    
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', '广东':'https://assets.pyecharts.org/assets/v5/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="e74102f1579147689d13b9acacca8be6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_e74102f1579147689d13b9acacca8be6 = echarts.init(
#                     document.getElementById('e74102f1579147689d13b9acacca8be6'), 'white', {renderer: 'canvas'});
#                 var option_e74102f1579147689d13b9acacca8be6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="Map-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="577acc9326024e9082c2dffa02d41d63" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_577acc9326024e9082c2dffa02d41d63 = echarts.init(
#                     document.getElementById('577acc9326024e9082c2dffa02d41d63'), 'white', {renderer: 'canvas'});
#                 var option_577acc9326024e9082c2dffa02d41d63 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(['北京市', '天津市', '河北省'], [34, 56, 98])], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="Map-基本示例"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="f803fde99f844299b1f231d166340f14" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f803fde99f844299b1f231d166340f14 = echarts.init(
#                     document.getElementById('f803fde99f844299b1f231d166340f14'), 'white', {renderer: 'canvas'});
#                 var option_f803fde99f844299b1f231d166340f14 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker



c = (
    Map()
#     .add("北京市", [list(z) for z in zip(['北京市'], [34])], "北京")
#     .add("天津市", [list(z) for z in zip(['天津市'], [56])], "天津")
    .add("河北省", [list(z) for z in zip(['河北省'], [ 98])], "河北")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts()
    )
    
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', '河北':'https://assets.pyecharts.org/assets/v5/maps/hebei'
#         }
#     });
# </script>
#
#         <div id="c29c5ceff4b8453e9fc827bd871a1d8f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '河北'], function(echarts) {
#                 var chart_c29c5ceff4b8453e9fc827bd871a1d8f = echarts.init(
#                     document.getElementById('c29c5ceff4b8453e9fc827bd871a1d8f'), 'white', {renderer: 'canvas'});
#                 var option_c29c5ceff4b8453e9fc827bd871a1d8f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...

# %%
Faker.provinces
# Out:
# ['广东省', '北京市', '上海市', '江西省', '湖南省', '浙江省', '江苏省']

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(['河北省', '北京市', '天津市市'], Faker.values())], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
        visualmap_opts=opts.VisualMapOpts(max_=200, is_piecewise=True),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="7a863205efa943969c2a473570b8a737" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_7a863205efa943969c2a473570b8a737 = echarts.init(
#                     document.getElementById('7a863205efa943969c2a473570b8a737'), 'white', {renderer: 'canvas'});
#                 var option_7a863205efa943969c2a473570b8a737 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
# ...
